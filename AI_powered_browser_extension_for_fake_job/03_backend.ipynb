# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install fastapi uvicorn pyngrok transformers torch

# %%
# %cd /content/drive/MyDrive/HireShield/backend
# Out:
# /content/drive/MyDrive/HireShield/backend

# %%
# !ls
# Out:
# app.py	__pycache__  server.log

# %%
# !nohup uvicorn app:app --host 0.0.0.0 --port 8000 > server.log 2>&1 &

# %%
from pyngrok import ngrok
ngrok.set_auth_token("39HyCoibANppa3UydkddHglRkeJ_7ia9is5T6bJm26qAJGSgG")
public_url = ngrok.connect(8000)
print(public_url)
# Out:
# NgrokTunnel: "https://unpearled-frederick-loxodromically.ngrok-free.dev" -> "http://localhost:8000"
